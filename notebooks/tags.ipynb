# %%
import os.path
import urllib.request
from bs4 import BeautifulSoup

# %%
ARTICLES = set()
PAGES = set()

def parse(quote_page):
    """ Parse the Page """

    if quote_page not in PAGES:
        print("Currently processing " + quote_page)
        PAGES.add(quote_page)

        page = urllib.request.urlopen(quote_page)
        soup = BeautifulSoup(page, 'html.parser')

        for link in soup.find_all('a'):
            ref = link.get('href')
            if 'faceted_query' not in ref:
                ARTICLES.add(ref)
            else:
                parse(ref)

# %% [markdown]
# ```
# <h6 class="sidebar-heading">Topic</h6><ul class="sidebar-navmenu">
#     <li class="open">
#         <a href="https://www.enisa.europa.eu/topics/critical-information-infrastructures-and-services">Critical Infrastructures and Services</a>
#         <ul>
#             <li class="active"><a href="https://www.enisa.europa.eu/topics/critical-information-infrastructures-and-services/cii">Critical Information Infrastructures</a></li>
#         </ul>
#     </li>
# </ul>
#
# <h6 class="sidebar-heading">Keywords</h6><ul class="list-unstyled">
#     <li>
#         <a href="https://www.enisa.europa.eu/@@search?Subject%3Alist=Critical%20Information%20Infrastructure%20Protection%20%28CIIP%29">Critical Information Infrastructure Protection (CIIP)</a>
#     </li>
# </ul>
# ```

# %%
TOPICS = set()
KEYWORDS = set()

def get_tags(link):
    """Get topic and keywords"""

    name = link.split('/')[-1]
    
    topics = set()
    keywords = set()
    
    page = urllib.request.urlopen(link)
    soup = BeautifulSoup(page, 'html.parser')

    for link in soup.find_all('a'):
        ref = link.get('href')
        if "https://www.enisa.europa.eu/topics/" in ref:
            topics.add(link.string)
            TOPICS.add(link.string)
        if "https://www.enisa.europa.eu/@@search?Subject" in ref:
            keywords.add(link.string)
            KEYWORDS.add(link.string)
    
    return name, list(topics), list(keywords)

# %%
start_page = 'https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=0'
parse(start_page)
# Out:
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=0
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=20
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=40
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=60
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=80
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=100
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=120
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=140
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=160
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=180
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=200
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=220
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=240
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=260
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=280
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=300
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=320
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=340
# Currently processing https://www.enisa.europa.eu/publications/@@faceted_query?b_start:int=360

# %%
import pandas as pd

tags = pd.DataFrame(columns=['name', 'topics', 'keywords'])

idx = 0
for ref in ARTICLES:
    name, topics, keywords = get_tags(ref)
    
    print('-' * 80)
    print(name)
    print('-' * 80)
    print(topics)
    print(keywords)
    
    tags.loc[idx] = [name, topics, keywords]
    idx += 1
# Out:
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-estonian
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-russian
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# []
# --------------------------------------------------------------------------------
# standards-and-tools-for-exchange-and-processing-of-actionable-information
# --------------------------------------------------------------------------------
# ['CSIRT Services', 'Reactive Services']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-irish
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# cyber-europe-2012-key-findings-report
# --------------------------------------------------------------------------------
# ['Cyber Exercises', 'Cyber Europe']
# ['Crisis Management']
# --------------------------------------------------------------------------------
# improving-cooperation-between-csirts-and-law-enforcement
# --------------------------------------------------------------------------------
# ['CSIRTs and communities', 'Law Enforcement']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# survey-pat
# --------------------------------------------------------------------------------
# ['Online and mobile data protection', 'Data Protection']
# ['Identity & Trust', 'Privacy']
# --------------------------------------------------------------------------------
# tf-tdca
# --------------------------------------------------------------------------------
# ['Public Private Partnerships (PPPs)', 'National Cyber Security Strategies']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# flash-note-can-recent-attacks-really-threaten-internet-availability
# --------------------------------------------------------------------------------
# []
# []
# --------------------------------------------------------------------------------
# incident-reporting-for-cloud-computing
# --------------------------------------------------------------------------------
# ['Cloud and Big Data', 'Cloud Security']
# ['Incident Reporting', 'Cloud Computing Security']
# --------------------------------------------------------------------------------
# art4_tech
# --------------------------------------------------------------------------------
# ['Data Protection', 'Personal data breaches']
# ['Privacy']
# --------------------------------------------------------------------------------
# recommendations-on-european-data-protection-certification
# --------------------------------------------------------------------------------
# ['Standards and certification', 'Data Protection']
# ['Privacy', 'Data protection']
# --------------------------------------------------------------------------------
# security-guide-for-ict-procurement
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# cloud-computing-information-assurance-framework
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# []
# --------------------------------------------------------------------------------
# ce2014-after-action-report
# --------------------------------------------------------------------------------
# ['Cyber Exercises', 'Cyber Europe']
# ['Crisis Management']
# --------------------------------------------------------------------------------
# report
# --------------------------------------------------------------------------------
# ['International Conferences', 'Cyber Crisis Management']
# ['Cyber crisis cooperation']
# --------------------------------------------------------------------------------
# to-log-or-not-to-log-risks-and-benefits-of-emerging-life-logging-applications
# --------------------------------------------------------------------------------
# ['Threat Landscape', 'Threat and Risk Management', 'Emerging and Future Risks']
# ['Network and Information Security Awareness', 'European Union Institutions', 'Privacy', 'Identity & Trust', 'Risk Management']
# --------------------------------------------------------------------------------
# enisa-threat-landscape-2013-overview-of-current-and-emerging-cyber-threats
# --------------------------------------------------------------------------------
# ['Threat Landscape', 'ENISA Threat Landscape', 'Threat and Risk Management']
# ['Threat Intelligence']
# --------------------------------------------------------------------------------
# using-taxonomies-in-incident-prevention-detection
# --------------------------------------------------------------------------------
# ['CSIRT Services']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# exploring-cloud-incidents
# --------------------------------------------------------------------------------
# ['Cloud and Big Data', 'Cloud Security']
# ['Cloud Computing Security']
# --------------------------------------------------------------------------------
# strategies-for-incident-response-and-cyber-crisis-cooperation
# --------------------------------------------------------------------------------
# ['EU-level Cyber Crisis Management', 'Cyber Crisis Management', 'CSIRT Services', 'Reactive Services']
# ['Exercises', 'CSIRTs']
# --------------------------------------------------------------------------------
# cyber-security-aspects-in-the-maritime-sector-1
# --------------------------------------------------------------------------------
# ['Maritime']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# indispensable-baseline-security-requirements-for-the-procurement-of-secure-ict-products-and-services
# --------------------------------------------------------------------------------
# []
# ['Standards', 'Cyber Security', 'Procurement']
# --------------------------------------------------------------------------------
# security-and-resilience-in-ehealth-infrastructures-and-services
# --------------------------------------------------------------------------------
# ['Health', 'Critical Infrastructures and Services']
# ['Health', 'Critical Information Infrastructure Protection (CIIP)', 'Resilience']
# --------------------------------------------------------------------------------
# the-right-to-be-forgotten
# --------------------------------------------------------------------------------
# ['Online and mobile data protection', 'Data Protection']
# ['Identity & Trust', 'Privacy']
# --------------------------------------------------------------------------------
# ontology_taxonomies
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'Critical Information Infrastructures']
# ['Resilience']
# --------------------------------------------------------------------------------
# pets-maturity-tool
# --------------------------------------------------------------------------------
# ['Privacy enhancing technologies', 'Data Protection']
# ['Data protection']
# --------------------------------------------------------------------------------
# trusted-egov
# --------------------------------------------------------------------------------
# ['Security measures', 'Trust Services']
# ['Trust service providers']
# --------------------------------------------------------------------------------
# survey-and-analysis-of-security-parameters-in-cloud-slas-across-the-european-public-sector
# --------------------------------------------------------------------------------
# ['Cloud and Big Data', 'Cloud Security']
# ['Cloud Computing Security']
# --------------------------------------------------------------------------------
# security-guidelines-on-the-appropriate-use-of-qualified-electronic-time-stamps
# --------------------------------------------------------------------------------
# ['Trust Services', 'Qualified trust services']
# ['Identity & Trust', 'Trust service providers', 'eID']
# --------------------------------------------------------------------------------
# definition-of-cybersecurity
# --------------------------------------------------------------------------------
# ['Standards and certification', 'Standards']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# smartphone-secure-development-guidelines
# --------------------------------------------------------------------------------
# []
# ['Internet of things']
# --------------------------------------------------------------------------------
# leading-the-way-enisa-s-impact-in-operational-security
# --------------------------------------------------------------------------------
# ['CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# stock-taking-of-information-security-training-needs-in-critical-sectors
# --------------------------------------------------------------------------------
# ['Trainings for Cyber Security Specialists']
# ['Training', 'CSIRTs']
# --------------------------------------------------------------------------------
# eidas-overview-on-the-implementation-and-uptake-of-trust-services
# --------------------------------------------------------------------------------
# ['Trust Services']
# ['Trust service providers', 'Trust Services', 'eIDAS']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-italian
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# article19-incident-reporting-framework
# --------------------------------------------------------------------------------
# ['Incident Reporting', 'For Trust Providers']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# tf-tis
# --------------------------------------------------------------------------------
# ['National Cyber Security Strategies', 'Information Sharing and Analysis Centers (ISACs)']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# data-collection
# --------------------------------------------------------------------------------
# ['Privacy by Design', 'Data Protection']
# ['Identity & Trust', 'Privacy']
# --------------------------------------------------------------------------------
# cloud-in-finance
# --------------------------------------------------------------------------------
# ['Finance', 'Critical Infrastructures and Services']
# ['Cloud Computing Security']
# --------------------------------------------------------------------------------
# appropriate-security-measures-for-smart-grids
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'Smart Grids']
# ['Critical Information Infrastructure Protection (CIIP)', 'Smart Grids']
# --------------------------------------------------------------------------------
# annual-incident-reports-2013
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting', 'Annual Reports']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# signalling-security-in-telecom-ss7-diameter-5g
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'Critical Information Infrastructures']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# enisa-report-on-resilient-internet-interconnections
# --------------------------------------------------------------------------------
# ['Internet Infrastructure', 'Critical Infrastructures and Services', 'Understanding the importance of the Internet Infrastructure...']
# ['Resilience']
# --------------------------------------------------------------------------------
# scalable-and-accepted-methods-for-trust-building
# --------------------------------------------------------------------------------
# []
# ['CSIRTs']
# --------------------------------------------------------------------------------
# copy_of_cookies
# --------------------------------------------------------------------------------
# ['Online and mobile data protection', 'Data Protection']
# ['Data protection']
# --------------------------------------------------------------------------------
# schemes-for-auditing-security-measures
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Resilience']
# --------------------------------------------------------------------------------
# status-report-2012
# --------------------------------------------------------------------------------
# ['CSIRT Capabilities', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# annual-incident-analysis-report-for-the-trust-service-providers
# --------------------------------------------------------------------------------
# ['Incident Reporting', 'For Trust Providers']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-german
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# []
# --------------------------------------------------------------------------------
# sci-2015
# --------------------------------------------------------------------------------
# []
# ['Resilience']
# --------------------------------------------------------------------------------
# cyber-security-strategies-paper
# --------------------------------------------------------------------------------
# ['National Cyber Security Strategies Guidelines & tools', 'National Cyber Security Strategies']
# ['European Union Institutions']
# --------------------------------------------------------------------------------
# COIT_Mitigation_Strategies_Final_Report
# --------------------------------------------------------------------------------
# ['Threat Landscape', 'Threat and Risk Management']
# ['Cyber Security', 'Mobile Security', 'Risk Management']
# --------------------------------------------------------------------------------
# cyber-incident-reporting-in-the-eu
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# flash-note-the-bash-shellshock-bug
# --------------------------------------------------------------------------------
# []
# ['Cyber Security']
# --------------------------------------------------------------------------------
# nlra-analysis-report
# --------------------------------------------------------------------------------
# ['Cyber Crisis Management']
# ['Crisis Management', 'Risk Management']
# --------------------------------------------------------------------------------
# guideline-on-security-measures-for-article-4-and-article-13a
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# survey-analysis
# --------------------------------------------------------------------------------
# ['CSIRT Services']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# cybersecurity-competitions-2014-the-status-in-europe
# --------------------------------------------------------------------------------
# ['Cyber Security Education', 'NIS in Education']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# proposal-for-one-security-framework-for-articles-4-and-13a
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# example-asset-identification-cards
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# []
# --------------------------------------------------------------------------------
# annual-incident-reports-2011
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting', 'Annual Reports']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# critical-cloud-computing
# --------------------------------------------------------------------------------
# ['Cloud and Big Data', 'Cloud Security']
# ['Critical Information Infrastructure Protection (CIIP)', 'Cloud Computing Security']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-danish
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# secure-communication
# --------------------------------------------------------------------------------
# ['CSIRTs and communities']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# tsp_standards_2015
# --------------------------------------------------------------------------------
# ['Standards and certification', 'Standards']
# ['eID']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-slovak
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# brokerage-model-for-network-and-information-security-in-education
# --------------------------------------------------------------------------------
# ['Cyber Security Education', 'NIS in Education']
# ['Network and Information Security Awareness']
# --------------------------------------------------------------------------------
# etl2015
# --------------------------------------------------------------------------------
# ['Cyber 7 - Seven messages to the Edge of Cyber-Space', 'ENISA Threat Taxonomy - A tool for structuring threat...', 'Threat Landscape', 'ENISA Threat Landscape', 'ETL 2015 Cyber Threats Poster', 'Cyber 7: Seven Messages to the Edge of Cyber-Space', 'ENISA threat landscape - Top 15 Cyber Threats 2015', 'Threat Taxonomy', 'Threat and Risk Management']
# ['Threat Intelligence']
# --------------------------------------------------------------------------------
# incentives-and-barriers-of-the-cyber-insurance-market-in-europe
# --------------------------------------------------------------------------------
# ['National Cyber Security Strategies Guidelines & tools', 'National Cyber Security Strategies']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# tsp-supervision
# --------------------------------------------------------------------------------
# ['Trust Services', 'Guidelines implementing eIDAS']
# ['Trust service providers', 'eID', 'Trust Services']
# --------------------------------------------------------------------------------
# can-we-learn-from-scada-security-incidents
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'ICS SCADA']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# botnets-10-tough-questions
# --------------------------------------------------------------------------------
# ['Internet Infrastructure', 'Critical Infrastructures and Services', 'Understanding the importance of the Internet Infrastructure...']
# []
# --------------------------------------------------------------------------------
# good-practices-for-an-eu-ics-testing-coordination-capability
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'ICS SCADA']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-spanish
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# []
# --------------------------------------------------------------------------------
# smart-grid-threat-landscape-and-good-practice-guide
# --------------------------------------------------------------------------------
# ['Threat Landscape', 'ENISA Thematic Landscapes', 'Threat and Risk Management']
# ['Threat Intelligence']
# --------------------------------------------------------------------------------
# standardisation-for-smes
# --------------------------------------------------------------------------------
# ['Standards and certification', 'Standards']
# ['Privacy']
# --------------------------------------------------------------------------------
# pat-study
# --------------------------------------------------------------------------------
# ['Online and mobile data protection', 'Data Protection']
# ['Identity & Trust', 'Privacy']
# --------------------------------------------------------------------------------
# privacy-considerations-of-online-behavioural-tracking
# --------------------------------------------------------------------------------
# ['Online and mobile data protection', 'Data Protection']
# ['Identity & Trust', 'Privacy']
# --------------------------------------------------------------------------------
# handbook-on-security-of-personal-data-processing
# --------------------------------------------------------------------------------
# ['Data Protection']
# ['SMEs', 'Personal Data', 'Privacy']
# --------------------------------------------------------------------------------
# algorithms-key-size-and-parameters-report-2014
# --------------------------------------------------------------------------------
# ['Security of personal data', 'Cryptographic protocols and tools']
# ['Privacy']
# --------------------------------------------------------------------------------
# tf-masim
# --------------------------------------------------------------------------------
# ['Public Private Partnerships (PPPs)', 'National Cyber Security Strategies']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# good-practice-guide-for-incident-management
# --------------------------------------------------------------------------------
# ['CSIRT Services']
# ['Incident Reporting', 'Incident Response', 'CSIRTs', 'Good Practice', 'Trainings']
# --------------------------------------------------------------------------------
# tsp-security
# --------------------------------------------------------------------------------
# ['Trust Services', 'Guidelines implementing eIDAS']
# ['Trust service providers', 'eID', 'Trust Services']
# --------------------------------------------------------------------------------
# securing-smart-airports
# --------------------------------------------------------------------------------
# ['IoT and Smart Infrastructures', 'Critical Infrastructures and Services', 'Smart Transport', 'Critical Information Infrastructures']
# ['Internet of things', 'Critical Information Infrastructure Protection (CIIP)', 'Smart Cities']
# --------------------------------------------------------------------------------
# on-the-security-privacy-and-usability-of-online-seals
# --------------------------------------------------------------------------------
# ['Online and mobile data protection', 'Data Protection']
# ['Identity & Trust']
# --------------------------------------------------------------------------------
# eu-cyber-cooperation-the-digital-frontline
# --------------------------------------------------------------------------------
# []
# ['Cyber Security']
# --------------------------------------------------------------------------------
# public-private-partnerships-ppp-cooperative-models
# --------------------------------------------------------------------------------
# ['Public Private Partnerships (PPPs)', 'National Cyber Security Strategies']
# ['Public Private Partnership']
# --------------------------------------------------------------------------------
# annual-incident-reports-2012
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting', 'Annual Reports']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# electronic-evidence-a-basic-guide-for-first-responders
# --------------------------------------------------------------------------------
# ['CSIRTs and communities', 'Law Enforcement']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# emergency-communications-stocktaking
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'Critical Information Infrastructures']
# ['Resilience']
# --------------------------------------------------------------------------------
# national-exercise-good-practice-guide
# --------------------------------------------------------------------------------
# ['Cyber Exercises']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# public-private-partnerships-in-network-and-information-security-education
# --------------------------------------------------------------------------------
# ['Cyber Security Education', 'NIS in Education']
# ['Network and Information Security Awareness']
# --------------------------------------------------------------------------------
# annual-incident-reports-2015
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting', 'Annual Reports']
# ['Incident Reporting', 'Cyber Security']
# --------------------------------------------------------------------------------
# pets-controls-matrix-a-systematic-approach-for-assessing-online-and-mobile-privacy-tools
# --------------------------------------------------------------------------------
# ['Privacy enhancing technologies', 'Data Protection']
# ['Privacy', 'Privacy Tools']
# --------------------------------------------------------------------------------
# protecting-industrial-control-systems.-recommendations-for-europe-and-member-states
# --------------------------------------------------------------------------------
# ['Protecting Industrial Control Systems. Recommendations for...', 'Critical Infrastructures and Services', 'ICS SCADA']
# ['Resilience']
# --------------------------------------------------------------------------------
# security-guidelines-on-the-appropriate-use-of-qualified-electronic-signatures
# --------------------------------------------------------------------------------
# ['Trust Services', 'Qualified trust services']
# ['Identity & Trust', 'Trust service providers', 'eID']
# --------------------------------------------------------------------------------
# looking-into-the-crystal-ball
# --------------------------------------------------------------------------------
# []
# ['Internet of things', 'Cryptography', 'Certification', 'Smart Cities', 'Smart Cars']
# --------------------------------------------------------------------------------
# the-directive-on-attacks-against-information-systems
# --------------------------------------------------------------------------------
# ['CSIRTs and communities', 'Law Enforcement']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# annex-i
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'ICS SCADA']
# ['Resilience']
# --------------------------------------------------------------------------------
# roadmap-for-nis-education-programmes-in-europe
# --------------------------------------------------------------------------------
# ['Cyber Security Education', 'NIS in Education']
# ['Network and Information Security Awareness']
# --------------------------------------------------------------------------------
# nis-directive-and-national-csirts
# --------------------------------------------------------------------------------
# ['CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-dutch
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# privacy-and-security-in-personal-data-clouds
# --------------------------------------------------------------------------------
# ['Online and mobile data protection', 'Data Protection']
# ['Privacy']
# --------------------------------------------------------------------------------
# maturity-levels
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'ICS SCADA']
# ['Critical Information Infrastructure Protection (CIIP)', 'Resilience']
# --------------------------------------------------------------------------------
# policy-industry-research
# --------------------------------------------------------------------------------
# ['Standards and certification', 'Standards']
# ['Privacy']
# --------------------------------------------------------------------------------
# commonality-of-risk-assessment-language-in-cyber-insurance
# --------------------------------------------------------------------------------
# []
# ['Cyber Security']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-polish
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# report-on-annual-privacy-forum-2012
# --------------------------------------------------------------------------------
# ['Data Protection']
# ['Privacy', 'European Union Institutions', 'Identity & Trust']
# --------------------------------------------------------------------------------
# mutual-aid-agreements
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'Critical Information Infrastructures']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# security-aspects-of-virtualization
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Cloud and Big Data']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# overview-of-the-practices-of-ict-certification-laboratories-in-europe
# --------------------------------------------------------------------------------
# ['Standards and certification', 'Certification']
# ['Certification']
# --------------------------------------------------------------------------------
# good-practice-guide-on-training-methodologies
# --------------------------------------------------------------------------------
# ['Trainings for Cyber Security Specialists']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# eid-cards-en
# --------------------------------------------------------------------------------
# ['Trust Services']
# ['eID']
# --------------------------------------------------------------------------------
# introduction-to-return-on-security-investment
# --------------------------------------------------------------------------------
# ['CSIRT Capabilities', 'CSIRTs in Europe']
# ['CSIRTs', 'Risk Management']
# --------------------------------------------------------------------------------
# baseline-capabilities-of-national-governmental-certs-summary
# --------------------------------------------------------------------------------
# []
# ['CSIRTs']
# --------------------------------------------------------------------------------
# supporting-the-cert-community-impact-analysis-and-roadmap
# --------------------------------------------------------------------------------
# ['CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# cyber-security-culture-in-organisations
# --------------------------------------------------------------------------------
# ['Cyber Security Education']
# ['Network and Information Security Awareness', 'Cyber Security']
# --------------------------------------------------------------------------------
# ecsm2016-deployment-report
# --------------------------------------------------------------------------------
# ['Cyber Security Education', 'European Cyber Security Month']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# qualified-website-authentication-certificates
# --------------------------------------------------------------------------------
# ['Trust Services', 'Qualified trust services']
# ['Trust service providers']
# --------------------------------------------------------------------------------
# security-guidelines-on-the-appropriate-use-of-qualified-website-authentication-certificates
# --------------------------------------------------------------------------------
# ['Trust Services', 'Qualified trust services']
# ['Identity & Trust', 'Trust service providers', 'eID']
# --------------------------------------------------------------------------------
# eisas-enhanced-roadmap-2012
# --------------------------------------------------------------------------------
# ['CSIRT Services']
# ['SMEs', 'Network and Information Security Awareness', 'Good Practice', 'CSIRTs', 'Trainings']
# --------------------------------------------------------------------------------
# good-practice-guide-for-certs-in-the-area-of-industrial-control-systems
# --------------------------------------------------------------------------------
# ['Industrial Control Systems/SCADA', 'CSIRTs and communities', 'ICS-SCADA']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# ce2010report
# --------------------------------------------------------------------------------
# ['Cyber Exercises', 'Cyber Europe']
# ['Crisis Management']
# --------------------------------------------------------------------------------
# latest-report-on-national-and-international-cyber-security-exercises
# --------------------------------------------------------------------------------
# ['Cyber Exercises']
# ['Crisis Management', 'Cyber crisis cooperation']
# --------------------------------------------------------------------------------
# privacy-and-data-protection-by-design
# --------------------------------------------------------------------------------
# ['Privacy by Design', 'Data Protection']
# ['Privacy']
# --------------------------------------------------------------------------------
# pets
# --------------------------------------------------------------------------------
# ['Privacy enhancing technologies', 'Data Protection']
# ['Privacy']
# --------------------------------------------------------------------------------
# protection-of-underground-infrastructure
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Resilience', 'Cyber Security']
# --------------------------------------------------------------------------------
# methodologies-for-the-identification-of-ciis
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'Critical Information Infrastructures']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# the-use-of-cryptographic-techniques-in-europe
# --------------------------------------------------------------------------------
# ['Security of personal data', 'Cryptographic protocols and tools']
# ['Identity & Trust']
# --------------------------------------------------------------------------------
# technical-guideline-on-incident-reporting
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Resilience']
# --------------------------------------------------------------------------------
# tsp3-incidents
# --------------------------------------------------------------------------------
# ['Security measures', 'Trust Services']
# ['Trust service providers']
# --------------------------------------------------------------------------------
# information-packages-for-small-and-medium-sized-enterprises-smes
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# []
# --------------------------------------------------------------------------------
# metrics-survey
# --------------------------------------------------------------------------------
# ['Internet Infrastructure', 'Critical Infrastructures and Services', 'Understanding the importance of the Internet Infrastructure...']
# ['Critical Information Infrastructure Protection (CIIP)', 'Resilience', 'Managed Services: Metrics']
# --------------------------------------------------------------------------------
# tsp-initiation
# --------------------------------------------------------------------------------
# ['Trust Services', 'Guidelines implementing eIDAS']
# ['Trust service providers', 'eID', 'Trust Services']
# --------------------------------------------------------------------------------
# implementation-of-article-15
# --------------------------------------------------------------------------------
# []
# ['Trust service providers']
# --------------------------------------------------------------------------------
# legal-information-sharing-1
# --------------------------------------------------------------------------------
# ['CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# a-collection-of-good-practice-for-cert-quality-assurance
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# []
# --------------------------------------------------------------------------------
# cooperation-between-certs-and-law-enforcement-agencies-in-the-fight-against-cybercrime-a-first-collection-of-practices
# --------------------------------------------------------------------------------
# ['CSIRTs and communities', 'Law Enforcement']
# ['Good Practice', 'CSIRTs', 'Trainings']
# --------------------------------------------------------------------------------
# who-is-who-directory-2011
# --------------------------------------------------------------------------------
# []
# []
# --------------------------------------------------------------------------------
# an-evaluation-framework-for-cyber-security-strategies
# --------------------------------------------------------------------------------
# ['National Cyber Security Strategies Guidelines & tools', 'National Cyber Security Strategies']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# ccc-study
# --------------------------------------------------------------------------------
# ['Cyber Crisis Management']
# ['Cyber crisis procedures', 'Cyber crisis cooperation']
# --------------------------------------------------------------------------------
# technology-induced-challenges-in-privacy-data-protection-in-europe
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# ['Identity & Trust', 'Trainings', 'Privacy']
# --------------------------------------------------------------------------------
# blockchain-security
# --------------------------------------------------------------------------------
# ['Finance', 'Critical Infrastructures and Services']
# ['Finance', 'Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# security-certification-practice-in-the-eu-information-security-management-systems-a-case-study
# --------------------------------------------------------------------------------
# ['Security measures', 'Security of personal data']
# ['Privacy']
# --------------------------------------------------------------------------------
# vulnerability-disclosure
# --------------------------------------------------------------------------------
# ['CSIRT Services', 'Quality Management']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# incident-notification-for-dsps-in-the-context-of-the-nis-directive
# --------------------------------------------------------------------------------
# ['Incident Reporting', 'For Digital Service Providers (NIS Directive)']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-greek
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# ncss-good-practice-guide
# --------------------------------------------------------------------------------
# ['National Cyber Security Strategies Guidelines & tools', 'National Cyber Security Strategies']
# ['National Cyber Security Strategies']
# --------------------------------------------------------------------------------
# cybersecurity-cooperation-defending-the-digital-frontline
# --------------------------------------------------------------------------------
# []
# ['Trainings']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide
# --------------------------------------------------------------------------------
# ['Setting up guide project plan in XML', 'CSIRT Cooperation', 'CSIRTs in Europe', 'Setting up guide project plan in MPP']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# copy_of_procent
# --------------------------------------------------------------------------------
# []
# ['Cyber Security']
# --------------------------------------------------------------------------------
# study-on-csirt-maturity
# --------------------------------------------------------------------------------
# ['CSIRT Capabilities', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# business-continuity-for-smes
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# []
# --------------------------------------------------------------------------------
# good-practice-guide-for-addressing-network-and-information-security-aspects-of-cybercrime
# --------------------------------------------------------------------------------
# ['CSIRTs and communities', 'Law Enforcement']
# ['CSIRTs', 'Good Practice', 'Trainings']
# --------------------------------------------------------------------------------
# europeansecuritymonth
# --------------------------------------------------------------------------------
# ['Cyber Security Education', 'European Cyber Security Month']
# ['Network and Information Security Awareness', 'Good Practice']
# --------------------------------------------------------------------------------
# technical-guideline-on-minimum-security-measures
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Resilience']
# --------------------------------------------------------------------------------
# status-of-privacy-and-nis-course-curricula-in-eu-member-states
# --------------------------------------------------------------------------------
# ['Cyber Security Education', 'NIS in Education']
# ['Privacy', 'Network and Information Security Awareness']
# --------------------------------------------------------------------------------
# policy-statement
# --------------------------------------------------------------------------------
# ['Internet Infrastructure', 'Critical Infrastructures and Services', 'Understanding the importance of the Internet Infrastructure...']
# []
# --------------------------------------------------------------------------------
# improving-recognition-of-ict-security-standards
# --------------------------------------------------------------------------------
# ['Standards and certification', 'Standards']
# ['Standards']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-finnish
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# updated-recommendations-2012
# --------------------------------------------------------------------------------
# ['CSIRT Capabilities', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# annex-vi
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'ICS SCADA']
# ['Resilience']
# --------------------------------------------------------------------------------
# ep3r-2009-2013
# --------------------------------------------------------------------------------
# ['Public Private Partnerships (PPPs)', 'National Cyber Security Strategies']
# ['Public Private Partnership']
# --------------------------------------------------------------------------------
# technical-guideline-on-threats-and-assets
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-latvian
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# exercise-survey2012
# --------------------------------------------------------------------------------
# ['Cyber Exercises']
# ['Crisis Management']
# --------------------------------------------------------------------------------
# botnets-measurement-detection-disinfection-and-defence
# --------------------------------------------------------------------------------
# ['Internet Infrastructure', 'Critical Infrastructures and Services', 'Understanding the importance of the Internet Infrastructure...']
# []
# --------------------------------------------------------------------------------
# security-incidents-indicators
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# cyber-hygiene
# --------------------------------------------------------------------------------
# ['Cyber Security Education']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# proactive-detection-report
# ...
# --------------------------------------------------------------------------------
# standards-eidas
# --------------------------------------------------------------------------------
# ['Standards and certification', 'Standards']
# ['Standards', 'Trust service providers']
# --------------------------------------------------------------------------------
# smartphone-secure-development-guidelines-2016
# --------------------------------------------------------------------------------
# []
# ['Internet of things', 'Mobile Applications', 'Mobile Security']
# --------------------------------------------------------------------------------
# appstore-security-5-lines-of-defence-against-malware
# --------------------------------------------------------------------------------
# []
# ['Internet of things', 'Good Practice']
# --------------------------------------------------------------------------------
# proactive-detection-of-security-incidents-II-honeypots
# --------------------------------------------------------------------------------
# ['Proactive detection of incidents', 'CSIRT Services', 'Proactive Services']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# communication-network-interdependencies-in-smart-grids
# --------------------------------------------------------------------------------
# ['Communication network interdependencies in smart grids ...', 'Critical Infrastructures and Services', 'Smart Grids']
# ['Critical Information Infrastructure Protection (CIIP)', 'Resilience', 'Smart Grids']
# --------------------------------------------------------------------------------
# gaps-eu-standardisation
# --------------------------------------------------------------------------------
# ['Standards and certification']
# ['Standards']
# --------------------------------------------------------------------------------
# securing-personal-data-in-the-context-of-data-retention
# --------------------------------------------------------------------------------
# ['Security measures', 'Security of personal data']
# ['Privacy']
# --------------------------------------------------------------------------------
# behavioural-biometrics
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# []
# --------------------------------------------------------------------------------
# tools-and-methodologies-to-support-cooperation-between-csirts-and-law-enforcement
# --------------------------------------------------------------------------------
# ['CSIRTs and communities', 'Law Enforcement']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# recommended-cryptographic-measures-securing-personal-data
# --------------------------------------------------------------------------------
# ['Security of personal data', 'Cryptographic protocols and tools']
# ['Cyber Security']
# --------------------------------------------------------------------------------
# eu-level-crisis-man
# --------------------------------------------------------------------------------
# ['EU-level Cyber Crisis Management', 'Cyber Crisis Management']
# ['Exercises', 'Crisis Management']
# --------------------------------------------------------------------------------
# tsp-standards
# --------------------------------------------------------------------------------
# ['Trust Services', 'Guidelines implementing eIDAS']
# ['Trust service providers', 'eID', 'Trust Services']
# --------------------------------------------------------------------------------
# xborderauth
# --------------------------------------------------------------------------------
# ['Trust Services']
# ['eID']
# --------------------------------------------------------------------------------
# mobile-payments-security
# --------------------------------------------------------------------------------
# ['Finance', 'Critical Infrastructures and Services']
# ['Mobile Security']
# --------------------------------------------------------------------------------
# eisas-report-on-implementation-enhanced
# --------------------------------------------------------------------------------
# ['CSIRTs and communities']
# ['SMEs', 'Network and Information Security Awareness', 'Online Safety', 'CSIRTs', 'Trainings']
# --------------------------------------------------------------------------------
# certification-of-cyber-security-skills-of-ics-scada-professionals
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'ICS SCADA']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# security-guidelines-on-the-appropriate-use-of-qualified-electronic-registered-delivery-services
# --------------------------------------------------------------------------------
# ['Trust Services', 'Qualified trust services']
# ['Identity & Trust', 'Trust service providers', 'eID']
# --------------------------------------------------------------------------------
# security-guidelines-on-the-appropriate-use-of-qualified-electronic-seals
# --------------------------------------------------------------------------------
# ['Trust Services', 'Qualified trust services']
# ['Identity & Trust', 'Trust service providers', 'eID']
# --------------------------------------------------------------------------------
# network-and-information-security-in-the-finance-sector
# --------------------------------------------------------------------------------
# ['Finance', 'Critical Infrastructures and Services']
# ['Resilience', 'Cyber Security']
# --------------------------------------------------------------------------------
# annex-v
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'ICS SCADA']
# ['Resilience']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-swedish
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# annual-incident-reports-2016
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Incident Reporting']
# --------------------------------------------------------------------------------
# cyber-security-and-resilience-for-smart-hospitals
# --------------------------------------------------------------------------------
# ['Health', 'Smart Infrastructure', 'Critical Infrastructures and Services', 'IoT and Smart Infrastructures']
# ['Health', 'Internet of things']
# --------------------------------------------------------------------------------
# national-roaming-for-resilience
# --------------------------------------------------------------------------------
# ['For Telcos', 'Incident Reporting']
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# mami
# --------------------------------------------------------------------------------
# ['Trust Services']
# ['eID']
# --------------------------------------------------------------------------------
# information-sharing-and-analysis-center-isacs-cooperative-models
# --------------------------------------------------------------------------------
# ['National Cyber Security Strategies', 'Information Sharing and Analysis Centers (ISACs)']
# ['Public Private Partnership']
# --------------------------------------------------------------------------------
# annual-privacy-forum-2016
# --------------------------------------------------------------------------------
# ['Data Protection']
# ['Privacy']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-hindi
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# exploring-the-opportunities-and-limitations-of-current-threat-intelligence-platforms
# --------------------------------------------------------------------------------
# ['Threat and Risk Management']
# ['Cyber Threat Intelligence']
# --------------------------------------------------------------------------------
# study-on-cryptographic-protocols
# --------------------------------------------------------------------------------
# ['Security of personal data', 'Cryptographic protocols and tools']
# ['Privacy']
# --------------------------------------------------------------------------------
# good-practice-guide-on-cooperatve-models-for-effective-ppps
# --------------------------------------------------------------------------------
# ['Public Private Partnerships (PPPs)', 'National Cyber Security Strategies']
# ['Public Private Partnership']
# --------------------------------------------------------------------------------
# awa
# --------------------------------------------------------------------------------
# ['CSIRT Services', 'Reactive Services']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# the-cost-of-incidents-affecting-ciis
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'Critical Information Infrastructures']
# ['Critical Information Infrastructure Protection (CIIP)', 'Resilience']
# --------------------------------------------------------------------------------
# ce2016-after-action-report
# --------------------------------------------------------------------------------
# ['Cyber Exercises', 'Cyber Europe']
# ['Crisis Management', 'Cyber Security']
# --------------------------------------------------------------------------------
# information-sharing-in-the-energy-sector
# --------------------------------------------------------------------------------
# ['CSIRTs and communities', 'Energy']
# ['Critical Information Infrastructure Protection (CIIP)', 'Cyber Security']
# --------------------------------------------------------------------------------
# procure-secure-a-guide-to-monitoring-of-security-service-levels-in-cloud-contracts
# --------------------------------------------------------------------------------
# ['Cloud and Big Data', 'Cloud Security']
# ['Cloud Computing Security']
# --------------------------------------------------------------------------------
# cloud-computing-risk-assessment
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Cloud Computing Risk Assessment - Spanish', 'Risk Management']
# ['Risk Management', 'Cloud Computing Security']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-bulgarian
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# big-data-security
# --------------------------------------------------------------------------------
# ['Big data', 'Cloud and Big Data']
# ['Big Data', 'Cloud Computing Security']
# --------------------------------------------------------------------------------
# pets-evolution-and-state-of-the-art
# --------------------------------------------------------------------------------
# ['Privacy enhancing technologies', 'Data Protection']
# ['Privacy', 'Privacy Tools']
# --------------------------------------------------------------------------------
# cert-cooperation-and-its-further-facilitation-by-relevant-stakeholders
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# eisas-basic-toolset
# --------------------------------------------------------------------------------
# ['CSIRTs and communities']
# ['SMEs', 'Network and Information Security Awareness', 'Online Safety', 'CSIRTs', 'Trainings']
# --------------------------------------------------------------------------------
# technology-induced-challenges-in-privacy-data-protection-in-europe-german-version
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# ['Identity & Trust', 'Trainings', 'Privacy']
# --------------------------------------------------------------------------------
# annex-iii
# --------------------------------------------------------------------------------
# ['Critical Infrastructures and Services', 'ICS SCADA']
# ['Resilience']
# --------------------------------------------------------------------------------
# guidelines-for-smes-on-the-security-of-personal-data-processing
# --------------------------------------------------------------------------------
# ['Data Protection']
# ['SMEs', 'Personal Data', 'Privacy']
# --------------------------------------------------------------------------------
# threat-landscape-for-smart-home-and-media-convergence
# --------------------------------------------------------------------------------
# ['Threat Landscape', 'ENISA Thematic Landscapes', 'Threat and Risk Management']
# ['Threat Intelligence']
# --------------------------------------------------------------------------------
# good-practices-recommendations
# --------------------------------------------------------------------------------
# ['IoT and Smart Infrastructures', 'Smart Transport']
# ['Internet of things', 'Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# the-threat-from-flamer
# --------------------------------------------------------------------------------
# []
# ['Critical Information Infrastructure Protection (CIIP)']
# --------------------------------------------------------------------------------
# risk-management-principles-and-inventories-for-risk-management-risk-assessment-methods-and-tools
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# []
# --------------------------------------------------------------------------------
# metrics-tech-report
# --------------------------------------------------------------------------------
# ['Internet Infrastructure', 'Critical Infrastructures and Services', 'Understanding the importance of the Internet Infrastructure...']
# ['Critical Information Infrastructure Protection (CIIP)', 'Resilience', 'Managed Services: Metrics']
# --------------------------------------------------------------------------------
# cloud-computing-sme-survey
# --------------------------------------------------------------------------------
# ['Threat and Risk Management', 'Risk Management']
# []
# --------------------------------------------------------------------------------
# eisas_roadmap
# --------------------------------------------------------------------------------
# ['CSIRTs and communities']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# csirt-setting-up-guide-in-portugese
# --------------------------------------------------------------------------------
# ['CSIRT Cooperation', 'CSIRTs in Europe']
# ['CSIRTs']
# --------------------------------------------------------------------------------
# egov
# --------------------------------------------------------------------------------
# ['Trust Services']
# ['eID']
# --------------------------------------------------------------------------------
# iitl
# --------------------------------------------------------------------------------
# ['Internet Infrastructure', 'ENISA Thematic Landscapes', 'Critical Infrastructures and Services', 'Threat Landscape', 'Threat Mind Map', 'Poster - Threats Against the Internet Infrastructure', 'Detailed Mind Map for Internet Infrastructure Assets', 'Threat and Risk Management']
# ['Threat Intelligence', 'Critical Information Infrastructure Protection (CIIP)']

# %%
tags.head()
# Out:
#                                                 name  \
# 0                 csirt-setting-up-guide-in-estonian
# 1                  csirt-setting-up-guide-in-russian
# 2  standards-and-tools-for-exchange-and-processin...
# 3                    csirt-setting-up-guide-in-irish
# 4              cyber-europe-2012-key-findings-report
#
#                                   topics             keywords
# 0  [CSIRT Cooperation, CSIRTs in Europe]             [CSIRTs]
# 1  [CSIRT Cooperation, CSIRTs in Europe]                   []
# 2    [CSIRT Services, Reactive Services]             [CSIRTs]
# 3  [CSIRT Cooperation, CSIRTs in Europe]             [CSIRTs]
# 4        [Cyber Exercises, Cyber Europe]  [Crisis Management]

# %%
print(len(TOPICS))
sorted(TOPICS)
# Out:
# 94
# ['Annual Reports',
#  'Big data',
#  'CIIP Governance in the EU (Annex)',
#  'CSIRT Capabilities',
#  'CSIRT Cooperation',
#  'CSIRT Services',
#  'CSIRTs and communities',
#  'CSIRTs in Europe',
#  'Certification',
#  'Cloud Computing Risk Assessment - Spanish',
#  'Cloud Security',
#  'Cloud and Big Data',
#  'Communication network interdependencies in smart grids ...',
#  'Community Projects',
#  'Critical Information Infrastructures',
#  'Critical Infrastructures and Services',
#  'Cryptographic protocols and tools',
#  'Cyber 7 - Seven messages to the Edge of Cyber-Space',
#  'Cyber 7: Seven Messages to the Edge of Cyber-Space',
#  'Cyber Crisis Management',
#  'Cyber Europe',
#  'Cyber Exercises',
#  'Cyber Security Education',
#  'Data Protection',
#  'Detailed Mind Map for Internet Infrastructure Assets',
#  'ECSM 2016 Planning',
#  'ECSM countries profiles',
#  'ENISA Thematic Landscapes',
#  'ENISA Threat Landscape',
#  'ENISA Threat Taxonomy - A tool for structuring threat...',
#  'ENISA threat landscape - Top 15 Cyber Threats 2015',
#  'ETL 2015 Cyber Threats Poster',
#  'EU-level Cyber Crisis Management',
#  'Emerging and Future Risks',
#  'Energy',
#  'European Cyber Security Month',
#  'European Cyber Security Month Roadmap',
#  'European Cyber Security Month overview',
#  'Finance',
#  'For Digital Service Providers (NIS Directive)',
#  'For Telcos',
#  'For Trust Providers',
#  'Guidelines implementing eIDAS',
#  'Health',
#  'ICS SCADA',
#  'ICS-SCADA',
#  'ICT Inderdependencies of the smart grid',
#  'Incident Reporting',
#  'Industrial Control Systems/SCADA',
#  'Information Sharing and Analysis Centers (ISACs)',
#  'International Conferences',
#  'Internet Infrastructure',
#  'Internet of Things (IoT)',
#  'IoT and Smart Infrastructures',
#  'Law Enforcement',
#  'Maritime',
#  'NIS in Education',
#  'National Cyber Security Strategies',
#  'National Cyber Security Strategies Guidelines & tools',
#  'Network Information security in education - Infographics',
#  'Online and mobile data protection',
#  'Personal data breaches',
#  'Poster - Threats Against the Internet Infrastructure',
#  'Presentations for educational sessions',
#  'Privacy by Design',
#  'Privacy enhancing technologies',
#  'Proactive Services',
#  'Proactive detection of incidents',
#  'Protecting Industrial Control Systems. Recommendations for...',
#  'Public Private Partnerships (PPPs)',
#  'Qualified trust services',
#  'Quality Management',
#  'Reactive Services',
#  'Risk Management',
#  'Security Aspects of Smart Grid',
#  'Security measures',
#  'Security of personal data',
#  'Setting up guide project plan in MPP',
#  'Setting up guide project plan in XML',
#  'Smart Grid Security Related Standards Guidelines and...',
#  'Smart Grids',
#  'Smart Infrastructure',
#  'Smart Transport',
#  'Smart grid Security Related Initiatives',
#  'Standards',
#  'Standards and certification',
#  'Survey and Interview Analysis',
#  'Threat Landscape',
#  'Threat Mind Map',
#  'Threat Taxonomy',
#  'Threat and Risk Management',
#  'Trainings for Cyber Security Specialists',
#  'Trust Services',
#  'Understanding the importance of the Internet Infrastructure...']

# %%
print(len(KEYWORDS))
sorted(KEYWORDS)
# Out:
# 51
# ['Big Data',
#  'CSIRTs',
#  'Certification',
#  'Cloud Computing Security',
#  'Crisis Management',
#  'Critical Information Infrastructure Protection (CIIP)',
#  'Cryptography',
#  'Cyber Security',
#  'Cyber Threat Intelligence',
#  'Cyber Threats',
#  'Cyber crisis cooperation',
#  'Cyber crisis procedures',
#  'Data protection',
#  'Digital Skills',
#  'ENISA events',
#  'European Union Institutions',
#  'Exercises',
#  'Finance',
#  'Good Practice',
#  'Health',
#  'Identity & Trust',
#  'Incident Reporting',
#  'Incident Response',
#  'Internet of things',
#  'Managed Services: Metrics',
#  'Mobile Applications',
#  'Mobile Security',
#  'National Cyber Security Strategies',
#  'Network and Information Security Awareness',
#  'Online Safety',
#  'Personal Data',
#  'Privacy',
#  'Privacy Tools',
#  'Procurement',
#  'Public Private Partnership',
#  'Resilience',
#  'Risk Management',
#  'SCADA',
#  'SMEs',
#  'Smart Cars',
#  'Smart Cities',
#  'Smart Grids',
#  'Standards',
#  'Threat Intelligence',
#  'Threat landscape',
#  'Training',
#  'Trainings',
#  'Trust Services',
#  'Trust service providers',
#  'eID',
#  'eIDAS']

# %%
tags.to_csv('tags.csv', index=False)
